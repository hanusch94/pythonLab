# %% [markdown]
# # Ciklusok

# %%
# A ciklusokcélja az ismétlődő feladat szé

print(0)
print(1)
print(2)
print(3)
# Out:
# 0
# 1
# 2
# 3

# %% [markdown]
# ## While
# - A while addig fut újra, amíg a feltétele teljesül
# - Ha másképp szeretnénk mondani, akkor egy ismétlődő if-ről van szó

# %%
a = 0
while(a<3):
    print(a)
    a+=1
# Out:
# 0
# 1
# 2

# %% [markdown]
# ## For
# - Ha egy listán szeretnénk végigmenni, akkor a for ciklus tud megoldást adni számunkra

# %%
# Formátum: for [elem] in [lista]:
a = ["a", "b", "c", "d"]
for elem in a:
    print(elem)
# Out:
# a
# b
# c
# d

# %% [markdown]
# ## For i in range()

# %%
# A range() egy iterable (iterálható listát) hoz létre
# Ennek a tényleges belseje végigiterálva (végig lépkedve) oldható meg
print(range(10))
# Out:
# range(0, 10)

# %%
# Gyakorlati használatban
for lm in range(5):
    print(lm, end=" ")
# Out:
# 0 1 2 3 4

# %%
# A lista kezdőértékét tudjuk változtatni
for lm in range(10,15):
    print(lm, end=" ")
# Out:
# 10 11 12 13 14

# %%
# Ha a léptetésen szeretnénk változtatni, akkor a 3. paraméterrel lehet ezt megoldani
for lm in range(10,20, 2):
    print(lm, end=" ")
# Out:
# 10 12 14 16 18

# %% [markdown]
# # Végtelen ciklus!
# Gyakori probléma a ciklusokkal, hogy lefagyaszthatják az egész gépet, ha végtelenítve újra és újra futnak.

# %%
while(True):
    a = 1
# Out:
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# ...
